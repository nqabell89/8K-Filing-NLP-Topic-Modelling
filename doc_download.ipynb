# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cik_ticker.csv', sep='|')

# %%
df.head()
# Out:
#        CIK Ticker                              Name Exchange     SIC Business  \
# 0  1090872      A          Agilent Technologies Inc     NYSE  3825.0       CA
# 1     4281     AA                         Alcoa Inc     NYSE  3350.0       PA
# 2  1332552  AAACU  Asia Automotive Acquisition Corp      NaN  6770.0       DE
# 3  1287145   AABB                Asia Broadband Inc      OTC  8200.0       GA
# 4  1024015   AABC        Access Anytime Bancorp Inc      NaN  6035.0       NM
#
#   Incorporated          IRS
# 0           DE  770518772.0
# 1           PA  250317820.0
# 2           DE  203022522.0
# 3           NV  721569126.0
# 4           DE  850444597.0

# %%
df.Exchange = df.Exchange.astype(str)

# %%
df.shape
# Out:
# (13737, 8)

# %%
df = df[(df['Exchange'] == 'NYSE') | (df['Exchange'] == 'NASDAQ')]

# %%
df.shape
# Out:
# (5549, 8)

# %%
df.drop(columns=['Business', 'Incorporated', 'IRS'], inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#        CIK Ticker                                            Name Exchange  \
# 0  1090872      A                        Agilent Technologies Inc     NYSE
# 1     4281     AA                                       Alcoa Inc     NYSE
# 2  1099290    AAC  Sinocoking Coal & Coke Chemical Industries Inc   NASDAQ
# 3     6201    AAL                     American Airlines Group Inc   NASDAQ
# 4     8177   AAME                          Atlantic American Corp   NASDAQ
#
#       SIC
# 0  3825.0
# 1  3350.0
# 2  3312.0
# 3  4512.0
# 4  6311.0

# %%
df.CIK = df.CIK.astype(str)

# %%
df['CIK'] = df['CIK'].str.zfill(10)

# %%
df.head(30)
# Out:
#            CIK Ticker                                            Name  \
# 0   0001090872      A                        Agilent Technologies Inc
# 1   0000004281     AA                                       Alcoa Inc
# 2   0001099290    AAC  Sinocoking Coal & Coke Chemical Industries Inc
# 3   0000006201    AAL                     American Airlines Group Inc
# 4   0000008177   AAME                          Atlantic American Corp
# 5   0000706688    AAN                                      Aarons Inc
# 6   0001158114   AAOI                     Applied Optoelectronics Inc
# 7   0000824142   AAON                                        Aaon Inc
# 8   0001158449    AAP                          Advance Auto Parts Inc
# 9   0000320193   AAPL                                       Apple Inc
# 10  0001500217    AAT                       American Assets Trust Inc
# 11  0000801558     AB                              Cannon Express Inc
# ...

# %%
#Try number 2
df[df['CIK']=='0000861361']
df2 = df[df.index>560]
df2.head()
# Out:
#             CIK Ticker                            Name Exchange     SIC
# 561  0000861361   BEAV                               B   NASDAQ  2531.0
# 562  0001059272   BEBE                 Bebe Stores Inc   NASDAQ  2330.0
# 563  0001124941   BECN       Beacon Roofing Supply Inc   NASDAQ  5030.0
# 564  0000910079    BED  Bedford Property Investors Inc     NYSE  6798.0
# 565  0001057436    BEE  Strategic Hotels & Resorts Inc     NYSE  6798.0

# %%
#Try number 3
df2[df2['CIK']=='0000009092']
df3 = df2[df2.index>662]
df3.head()
# Out:
#             CIK Ticker                           Name Exchange     SIC
# 663  0000009092    BMI               Badger Meter Inc     NYSE  3824.0
# 664  0001275477    BMM  Bimini Capital Management Inc     NYSE  6798.0
# 665  0001307579   BMOM      Liqtech International Inc     NYSE  3590.0
# 666  0001289236    BMR        Biomed Realty Trust Inc     NYSE  6798.0
# 667  0001403475   BMRC          Bank Of Marin Bancorp   NASDAQ  6022.0

# %%
#Try number 4
df3[df3['CIK']=='0000831001']
df4 = df3[df3.index>783]
df4.head()
# Out:
#             CIK Ticker                          Name Exchange     SIC
# 784  0000831001      C                 Citigroup Inc     NYSE  6021.0
# 785  0000356028     CA                        Ca Inc   NASDAQ  7372.0
# 786  0001157762   CAAS  China Automotive Systems Inc   NASDAQ  3714.0
# 787  0001267130    CAB                   Cabelas Inc     NYSE  5940.0
# 788  0000750686    CAC          Camden National Corp   NASDAQ  6021.0

# %%
from sec_edgar_downloader import Downloader
dl = Downloader('data/')

# %%
for i in df4.index:
    dl.get("8-K", df4.CIK[i], after_date="20030101", include_amends=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-3e1d69f5564a> in <module>
#       1 for i in df4.index:
# ----> 2     dl.get("8-K", df4.CIK[i], after_date="20030101", include_amends=True)
#
# ...

# %% [markdown]
# 136624 8-ks, 1838 Companys, 82 gig
